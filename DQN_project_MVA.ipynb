# %% [markdown]
# **You may need to install [OpenCV](https://pypi.python.org/pypi/opencv-python) and [scikit-video](http://www.scikit-video.org/stable/).**

# %%
import keras
import numpy as np
import io
import base64
from IPython.display import HTML
import skvideo.io
import cv2
import json

from keras.models import Sequential,model_from_json
from keras.layers.core import Dense
from keras.optimizers import sgd
from keras.layers import Conv2D, MaxPooling2D, Activation, AveragePooling2D,Reshape,BatchNormalization
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # MiniProject #3: Deep Reinforcement Learning

# %% [markdown]
# __Notations__: $E_p$ is the expectation under probability $p$. Please justify each of your answer and widely comment your code.

# %% [markdown]
# # Context

# %% [markdown]
# In a reinforcement learning algorithm, we modelize each step $t$ as an action $a_t$ obtained from a state $s_t$, i.e. $\{(a_{t},s_{t})_{t\leq T}\}$ having the Markov property. We consider a discount factor $\gamma \in [0,1]$ that ensures convergence. The goal is to find among all the policies $\pi$, one that maximizes the expected reward:
#
# \begin{equation*}
# R(\pi)=\sum_{t\leq T}E_{p^{\pi}}[\gamma^t r(s_{t},a_{t})] \> ,
# \end{equation*}
#
# where:
# \begin{equation*}p^{\pi}(a_{0},a_{1},s_{1},...,a_{T},s_{T})=p(a_{0})\prod_{t=1}^{T}\pi(a_{t}|s_{t})p(s_{t+1}|s_{t},a_{t}) \> .
# \end{equation*}
#
# We note the $Q$-function:
#
# \begin{equation*}Q^\pi(s,a)=E_{p^{\pi}}[\sum_{t\leq T}\gamma^{t}r(s_{t},a_{t})|s_{0}=s,a_{0}=a] \> .
# \end{equation*}
#
# Thus, the optimal Q function is:
# \begin{equation*}
# Q^*(s,a)=\max_{\pi}Q^\pi(s,a) \> .
# \end{equation*}
#
# In this project, we will apply the deep reinforcement learning techniques to a simple game: an agent will have to learn from scratch a policy that will permit it maximizing a reward.

# %% [markdown]
# ## The environment, the agent and the game

# %% [markdown]
# ### The environment

# %% [markdown]
# ```Environment``` is an abstract class that represents the states, rewards, and actions to obtain the new state.

# %%
class Environment(object):
    def __init__(self):
        pass

    def act(self, act):
        """
        One can act on the environment and obtain its reaction:
        - the new state
        - the reward of the new state
        - should we continue the game?

        :return: state, reward, game_over
        """
        pass


    def reset(self):
        """
        Reinitialize the environment to a random state and returns
        the original state

        :return: state
        """
        pass
    
    def draw(self):
        """
        Visualize in the console or graphically the current state
        """
        pass

# %% [markdown]
# The method ```act``` allows to act on the environment at a given state $s_t$ (stored internally), via action $a_t$. The method will return the new state $s_{t+1}$, the reward $r(s_{t},a_{t})$ and determines if $t\leq T$ (*game_over*).
#
# The method ```reset``` simply reinitializes the environment to a random state $s_0$.
#
# The method ```draw``` displays the current state $s_t$ (this is useful to check the behavior of the Agent).
#
# We modelize $s_t$ as a tensor, while $a_t$ is an integer.

# %% [markdown]
# ### The Agent

# %% [markdown]
# The goal of the ```Agent``` is to interact with the ```Environment``` by proposing actions $a_t$ obtained from a given state $s_t$ to attempt to maximize its __reward__ $r(s_t,a_t)$. We propose the following abstract class:

# %%
class Agent(object):
    def __init__(self, epsilon=0.1, n_action=4):
        self.epsilon = epsilon
        self.n_action = n_action
    
    def set_epsilon(self,e):
        self.epsilon = e

    def act(self,s,train=True):
        """ This function should return the next action to do:
        an integer between 0 and 4 (not included) with a random exploration of epsilon"""
        if train:
            if np.random.rand() <= self.epsilon:
                a = np.random.randint(0, self.n_action, size=1)[0]
            else:
                a = self.learned_act(s)
        else: # in some cases, this can improve the performance.. remove it if poor performances
            a = self.learned_act(s)

        return a

    def learned_act(self,s):
        """ Act via the policy of the agent, from a given state s
        it proposes an action a"""
        pass

    def reinforce(self, s, n_s, a, r, game_over_):
        """ This function is the core of the learning algorithm. 
        It takes as an input the current state s_, the next state n_s_
        the action a_ used to move from s_ to n_s_ and the reward r_.
        
        Its goal is to learn a policy.
        """
        pass

    def save(self):
        """ This function returns basic stats if applicable: the
        loss and/or the model"""
        pass

    def load(self):
        """ This function allows to restore a model"""
        pass

# %% [markdown]
# ***
# __Question 1__:
# Explain the function act. Why is ```epsilon``` essential?

# %% [markdown]
# The function uses $\epsilon$-Greedy Policy,which allows agent to explore actions that are not stored as learned actions. This helps agent to find optimal actions.

# %% [markdown]
# ***
# ### The Game

# %% [markdown]
# The ```Agent``` and the ```Environment``` work in an interlaced way as in the following (take some time to understand this code as it is the core of the project)
#
# ```python
#
# epoch = 300
# env = Environment()
# agent = Agent()
#
#
# # Number of won games
# score = 0
# loss = 0
#
#
# for e in range(epoch):
#     # At each epoch, we restart to a fresh game and get the initial state
#     state = env.reset()
#     # This assumes that the games will end
#     game_over = False
#
#     win = 0
#     lose = 0
#
#     while not game_over:
#         # The agent performs an action
#         action = agent.act(state)
#
#         # Apply an action to the environment, get the next state, the reward
#         # and if the games end
#         prev_state = state
#         state, reward, game_over = env.act(action)
#
#         # Update the counters
#         if reward > 0:
#             win = win + reward
#         if reward < 0:
#             lose = lose -reward
#
#         # Apply the reinforcement strategy
#         loss = agent.reinforce(prev_state, state,  action, reward, game_over)
#
#     # Save as a mp4
#     if e % 10 == 0:
#         env.draw(e)
#
#     # Update stats
#     score += win-lose
#
#     print("Epoch {:03d}/{:03d} | Loss {:.4f} | Win/lose count {}/{} ({})"
#           .format(e, epoch, loss, win, lose, win-lose))
#     agent.save()
# ```

# %% [markdown]
# # The game, *eat cheese*

# %% [markdown]
# A rat runs on an island and tries to eat as much as possible. The island is subdivided into $N\times N$ cells, in which there are cheese (+0.5) and poisonous cells (-1). The rat has a visibility of 2 cells (thus it can see $5^2$ cells). The rat is given a time $T$ to accumulate as much food as possible. It can perform 4 actions: going up, down, left, right.
#
# The goal is to code an agent to solve this task that will learn by trial and error. We propose the following environment:

# %%
class Environment(object):
    def __init__(self, grid_size=10, max_time=500, temperature=0.1):
        grid_size = grid_size+4
        self.grid_size = grid_size
        self.max_time = max_time
        self.temperature = temperature

        #board on which one plays
        self.board = np.zeros((grid_size,grid_size))
        self.position = np.zeros((grid_size,grid_size))

        # coordinate of the cat
        self.x = 0
        self.y = 1

        # self time
        self.t = 0

        self.scale=16

        self.to_draw = np.zeros((max_time+2, grid_size*self.scale, grid_size*self.scale, 3))


    def draw(self,e):
        skvideo.io.vwrite(str(e) + '.mp4', self.to_draw)

    def get_frame(self,t):
        b = np.zeros((self.grid_size,self.grid_size,3))+128
        b[self.board>0,0] = 256
        b[self.board < 0, 2] = 256
        b[self.x,self.y,:]=256
        b[-2:,:,:]=0
        b[:,-2:,:]=0
        b[:2,:,:]=0
        b[:,:2,:]=0
        
        b =  cv2.resize(b, None, fx=self.scale, fy=self.scale, interpolation=cv2.INTER_NEAREST)

        self.to_draw[t,:,:,:]=b


    def act(self, action):
        """This function returns the new state, reward and decides if the
        game ends."""

        self.get_frame(int(self.t))

        self.position = np.zeros((self.grid_size, self.grid_size))

        self.position[0:2,:]= -1
        self.position[:,0:2] = -1
        self.position[-2:, :] = -1
        self.position[-2:, :] = -1

        self.position[self.x, self.y] = 1
        if action == 0:
            if self.x == self.grid_size-3:
                self.x = self.x-1
            else:
                self.x = self.x + 1
        elif action == 1:
            if self.x == 2:
                self.x = self.x+1
            else:
                self.x = self.x-1
        elif action == 2:
            if self.y == self.grid_size - 3:
                self.y = self.y - 1
            else:
                self.y = self.y + 1
        elif action == 3:
            if self.y == 2:
                self.y = self.y + 1
            else:
                self.y = self.y - 1
        else:
            RuntimeError('Error: action not recognized')

        self.t = self.t + 1
        reward = self.board[self.x, self.y]
        self.board[self.x, self.y] = 0
        game_over = self.t > self.max_time
        state = np.concatenate((self.board.reshape(self.grid_size, self.grid_size,1),
                        self.position.reshape(self.grid_size, self.grid_size,1)),axis=2)
        state = state[self.x-2:self.x+3,self.y-2:self.y+3,:]

        return state, reward, game_over

    def reset(self):
        """This function resets the game and returns the initial state"""

        self.x = np.random.randint(3, self.grid_size-3, size=1)[0]
        self.y = np.random.randint(3, self.grid_size-3, size=1)[0]


        bonus = 0.5*np.random.binomial(1,self.temperature,size=self.grid_size**2)
        bonus = bonus.reshape(self.grid_size,self.grid_size)

        malus = -1.0*np.random.binomial(1,self.temperature,size=self.grid_size**2)
        malus = malus.reshape(self.grid_size, self.grid_size)

        self.to_draw = np.zeros((self.max_time+2, self.grid_size*self.scale, self.grid_size*self.scale, 3))


        malus[bonus>0]=0

        self.board = bonus + malus

        self.position = np.zeros((self.grid_size, self.grid_size))
        self.position[0:2,:]= -1
        self.position[:,0:2] = -1
        self.position[-2:, :] = -1
        self.position[-2:, :] = -1
        self.board[self.x,self.y] = 0
        self.t = 0

        state = np.concatenate((
                               self.board.reshape(self.grid_size, self.grid_size,1),
                        self.position.reshape(self.grid_size, self.grid_size,1)),axis=2)

        state = state[self.x - 2:self.x + 3, self.y - 2:self.y + 3, :]
        return state

# %% [markdown]
# The following elements are important because they correspond to the hyper parameters for this project:

# %%
# parameters
size = 13
T=200
temperature=0.3
epochs_train=50 # set small when debugging
epochs_test=50 # set small when debugging

# display videos
def display_videos(name):
    video = io.open(name, 'r+b').read()
    encoded = base64.b64encode(video)
    return '''<video alt="test" controls>
                <source src="data:video/mp4;base64,{0}" type="video/mp4" />
             </video>'''.format(encoded.decode('ascii'))

# %% [markdown]
# __Question 2__ Explain the use of the arrays ```position``` and ```board```.

# %% [markdown]
# `position` shows where the rat is allowed to move, available space(0) and where it's not allowed to move borders (-1)
# `board` shows cheese (+0.5) and penalties(-1)

# %% [markdown]
# ## Random Agent

# %% [markdown]
# ***
# __Question 3__ Implement a random Agent (only ```learned_act``` needs to be implemented):

# %%
class RandomAgent(Agent):
    def __init__(self):
        super(RandomAgent, self).__init__()
        pass

    def learned_act(self, s):
        return np.random.randint(0, self.n_action)

# %% [markdown]
# ***
# ***
# __Question 4__ Visualize the game moves. You need to fill in the following function for the evaluation:

# %%
def test(agent,env,epochs,prefix=''):
    # Number of won games
    score = 0
        
    for e in range(epochs):
        
        ##### FILL IN HERE
        state = env.reset()
        over = False
        
        win = 0
        lose = 0
        
        while not over:
            action = agent.act(state)
            prev_state = state
            state, reward, over = env.act(action)
            
            if reward > 0:
                win = win + reward
            if reward < 0:
                lose = lose -reward
            
        # Save as a mp4
        env.draw(prefix+str(e))

        # Update stats
        score = score + win-lose

        print("Win/lose count {}/{}. Average score ({})"
              .format(win, lose, score/(1+e)))
    print('Final score: '+str(score/epochs))

# %%
# Initialize the game
env = Environment(grid_size=size, max_time=T,temperature=temperature)

# Initialize the agent!
agent = RandomAgent()

test(agent,env,epochs_test,prefix='random')
HTML(display_videos('random0.mp4'))
# Out:
# Win/lose count 10.0/17.0. Average score (-7.0)
# Win/lose count 12.0/16.0. Average score (-5.5)
# Win/lose count 9.5/21.0. Average score (-7.5)
# Win/lose count 9.5/18.0. Average score (-7.75)
# Win/lose count 8.5/7.0. Average score (-5.9)
# Win/lose count 10.0/10.0. Average score (-4.916666666666667)
# Win/lose count 15.0/11.0. Average score (-3.642857142857143)
# Win/lose count 13.0/7.0. Average score (-2.4375)
# Win/lose count 8.0/8.0. Average score (-2.1666666666666665)
# Win/lose count 10.5/14.0. Average score (-2.3)
# Win/lose count 10.0/12.0. Average score (-2.272727272727273)
# Win/lose count 10.5/14.0. Average score (-2.375)
# Win/lose count 13.5/16.0. Average score (-2.3846153846153846)
# Win/lose count 10.0/9.0. Average score (-2.142857142857143)
# Win/lose count 9.0/13.0. Average score (-2.2666666666666666)
# Win/lose count 7.0/13.0. Average score (-2.5)
# Win/lose count 12.0/13.0. Average score (-2.411764705882353)
# Win/lose count 9.0/15.0. Average score (-2.611111111111111)
# Win/lose count 10.0/13.0. Average score (-2.6315789473684212)
# Win/lose count 11.0/20.0. Average score (-2.95)
# Win/lose count 10.0/11.0. Average score (-2.857142857142857)
# Win/lose count 6.5/9.0. Average score (-2.840909090909091)
# Win/lose count 12.0/16.0. Average score (-2.891304347826087)
# Win/lose count 7.0/19.0. Average score (-3.2708333333333335)
# Win/lose count 10.5/18.0. Average score (-3.44)
# Win/lose count 11.5/14.0. Average score (-3.4038461538461537)
# Win/lose count 11.0/14.0. Average score (-3.388888888888889)
# Win/lose count 7.5/14.0. Average score (-3.5)
# Win/lose count 11.5/18.0. Average score (-3.603448275862069)
# Win/lose count 9.5/14.0. Average score (-3.6333333333333333)
# Win/lose count 13.0/17.0. Average score (-3.6451612903225805)
# Win/lose count 9.5/19.0. Average score (-3.828125)
# Win/lose count 8.5/14.0. Average score (-3.878787878787879)
# Win/lose count 9.0/10.0. Average score (-3.7941176470588234)
# Win/lose count 10.0/15.0. Average score (-3.8285714285714287)
# Win/lose count 5.0/16.0. Average score (-4.027777777777778)
# Win/lose count 7.0/13.0. Average score (-4.081081081081081)
# Win/lose count 8.0/14.0. Average score (-4.131578947368421)
# Win/lose count 9.0/9.0. Average score (-4.0256410256410255)
# Win/lose count 11.0/10.0. Average score (-3.9)
# Win/lose count 15.0/13.0. Average score (-3.7560975609756095)
# Win/lose count 12.0/12.0. Average score (-3.6666666666666665)
# Win/lose count 10.0/16.0. Average score (-3.7209302325581395)
# Win/lose count 9.5/3.0. Average score (-3.4886363636363638)
# Win/lose count 6.5/7.0. Average score (-3.422222222222222)
# Win/lose count 10.5/12.0. Average score (-3.380434782608696)
# Win/lose count 6.0/13.0. Average score (-3.4574468085106385)
# Win/lose count 9.5/19.0. Average score (-3.5833333333333335)
# Win/lose count 12.0/21.0. Average score (-3.693877551020408)
# Win/lose count 12.0/13.0. Average score (-3.64)
# Final score: -3.64
# <video alt="test" controls>
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %% [markdown]
# ***
# ## DQN

# %% [markdown]
# Let us assume here that $T=\infty$.
#
# ***
# __Question 5__ Let $\pi$ be a policy, show that:
#
# \begin{equation*}
# Q^{\pi}(s,a)=E_{(s',a')\sim p(.|s,a)}[r(s,a)+\gamma Q^{\pi}(s',a')]
# \end{equation*}
#
# Then, show that for the optimal policy $\pi^*$ (we assume its existence), the following holds:
#
# \begin{equation*}
# Q^{*}(s,a)=E_{s'\sim \pi^*(.|s,a)}[r(s,a)+\gamma\max_{a'}Q^{*}(s',a')].
# \end{equation*}
# Finally, deduce that a plausible objective is:
#
# \begin{equation*}
# \mathcal{L}(\theta)=E_{s' \sim \pi^*(.|s,a)}\Vert r+\gamma\max\max_{a'}Q(s',a',\theta)-Q(s,a,\theta)\Vert^{2}.
# \end{equation*}

# %% [markdown]
# Proof
# \begin{align*}
#     Q^\pi(s,a)
#     &= \mathbb{E}\left[\sum_t \gamma^{t}r(s_t,a_t)|s_0=s,a_0=a, \forall t \ge 1, a_t=\pi(s_t)\right] \\
#     &= r(a, s) + \gamma \sum_{s'} \mathbb{P}(s_1 = s' | s_0 = s) \mathbb{E}\left[\sum_{t \ge 1} \gamma^{t - 1} r(s_t,a_t)|s_1=s',a_1=a'=\pi(s), \forall t \ge 1, a_t=\pi(s_t)\right] \\
#     &= E_{(s',a')\sim p(.|s,a)}\left[r(s,a)+\gamma Q^{\pi}(s',a')\right]
# \end{align*}
#
# Then,
# \begin{align*}
#     Q^{*}(s, a)
#     &= \max_{\pi} Q^{\pi}(s, a) \\
#     &= \max_{\pi} \left[ r(a, s) + \gamma \sum_{s'} \mathbb{P}(s_1 = s' | s_0 = s) Q^\pi(s', \pi(s)) \right] \\
#     &= r(a, s) + \gamma \sum_{s'} \mathbb{P}(s_1 = s' | s_0 = s) \max_{a'} Q^{*}(s', a') \\
#     &= E_{s'\sim \pi^*(.|s,a)}\left[r(s,a)+\gamma\max_{a'}Q^{*}(s',a')\right]
# \end{align*}
#
# \begin{align*}
#     &\iff 0 = E_{s'\sim \pi^*(.|s,a)}\left[r(s,a)+\gamma\max_{a'}Q^{*}(s',a')\right] -  Q^{*}(s, a) \\
#     &\iff 0 = E_{s'\sim \pi^*(.|s,a)}\left[r(s,a)+\gamma\max_{a'}Q^{*}(s',a') -  Q^{*}(s, a) \right]
# \end{align*}
#
# $$
#     \mathcal{L}(\theta)
#     = E_{s' \sim \pi^*(.|s,a)}\left[ \Vert r(s, a) +\gamma\max_{a'}Q(s',a',\theta)-Q(s,a,\theta)\Vert^{2} \right]
# $$

# %% [markdown]
# ***
# The DQN-learning algorithm relies on these derivations to train the parameters $\theta$ of a Deep Neural Network:
#
# 1. At the state $s_t$, select the action $a_t$ with best reward using $Q_t$ and store the results;
#
# 2. Obtain the new state $s_{t+1}$ from the environment $p$;
#
# 3. Store $(s_t,a_t,s_{t+1})$;
#
# 4. Obtain $Q_{t+1}$ by minimizing  $\mathcal{L}$ from a recovered batch from the previously stored results.
#
# ***
# __Question 6__ Implement the class ```Memory``` that stores moves (in a replay buffer) via ```remember``` and provides a ```random_access``` to these. Specify a maximum memory size to avoid side effects. You can for example use a ```list()``` and set by default ```max_memory=100```.

# %%
class Memory(object):
    def __init__(self, max_memory=100):
        self.max_memory = max_memory
        self.memory = list()

    def remember(self, m):
        self.memory = self.memory[1-self.max_memory:] + [m]

    def random_access(self):
        index = np.random.randint(0, len(self.memory))
        return self.memory[index]

# %% [markdown]
# ***
# The pipeline we will use for training is given below:

# %%
def train(agent,env,epoch,prefix=''):
    # Number of won games
    score = 0
    loss = 0

    for e in range(epoch):
        if (e%10 == 0):
            agent.Learning_rate = 1/(e/10+1)        
        # At each epoch, we restart to a fresh game and get the initial state
        state = env.reset()
        # This assumes that the games will terminate
        game_over = False

        win = 0
        lose = 0

        while not game_over:
            # The agent performs an action
            action = agent.act(state)

            # Apply an action to the environment, get the next state, the reward
            # and if the games end
            prev_state = state
            state, reward, game_over = env.act(action)

            # Update the counters
            if reward > 0:
                win = win + reward
            if reward < 0:
                lose = lose -reward

            # Apply the reinforcement strategy
            loss = agent.reinforce(prev_state, state,  action, reward, game_over)

        # Save as a mp4
        if e % 10 == 0:
            env.draw(prefix+str(e))

        # Update stats
        score += win-lose

        print("Epoch {:03d}/{:03d} | Loss {:.4f} | Win/lose count {}/{} ({})"
              .format(e, epoch, loss, win, lose, win-lose))
        agent.save(name_weights=prefix+'model.h5',name_model=prefix+'model.json')

# %% [markdown]
# ***
# __Question 7__ Implement the DQN training algorithm using a cascade of fully connected layers. You can use different learning rate, batch size or memory size parameters. In particular, the loss might oscillate while the player will start to win the games. You have to find a good criterium.

# %%
from keras.layers import Dense, Activation, Flatten

class DQN(Agent):
    def __init__(self, grid_size,  epsilon = 0.1, memory_size=100, batch_size = 16,n_state=2):
        super(DQN, self).__init__(epsilon = epsilon)

        # Discount for Q learning
        self.discount = 0.99
        
        self.grid_size = grid_size
        
        # number of state
        self.n_state = n_state

        # Memory
        self.memory = Memory(memory_size)
        
        # Batch size when learning
        self.batch_size = batch_size

    def learned_act(self, s):
        return np.argmax(self.model.predict(np.expand_dims(s, 0))[0])

    def reinforce(self, s_, n_s_, a_, r_, game_over_):
        # Two steps: first memorize the states, second learn from the pool

        self.memory.remember([s_, n_s_, a_, r_, game_over_])
        
        input_states = np.zeros((self.batch_size, 5,5,self.n_state))
        target_q = np.zeros((self.batch_size, 4))
        
        for i in range(self.batch_size):
            ######## FILL IN
            s, n_s, a, r, game_over = self.memory.random_access()
            input_states[i] = s.copy()
            target = self.model.predict(np.expand_dims(s, 0))[0]
            if game_over_:
                ######## FILL IN
                target[a] = r
            else:
                ######## FILL IN
                n_target= self.model.predict(np.expand_dims(n_s, 0))[0]
                target[a] = target[a] + self.Learning_rate*(r + self.discount*max(n_target)-target[a])
            target_q[i, :] = target.copy()
        ######## FILL IN
        # HINT: Clip the target to avoid exploiding gradients.. -- clipping is a bit tighter
        target_q = np.clip(target_q, -3, 3)

        l = self.model.train_on_batch(input_states, target_q)
        return l

    def save(self,name_weights='model.h5',name_model='model.json'):
        self.model.save_weights(name_weights, overwrite=True)
        with open(name_model, "w") as outfile:
            json.dump(self.model.to_json(), outfile)
            
    def load(self,name_weights='model.h5',name_model='model.json'):
        with open(name_model, "r") as jfile:
            model = model_from_json(json.load(jfile))
        model.load_weights(name_weights)
        model.compile("sgd", "mse")
        self.model = model

            
class DQN_FC(DQN):
    def __init__(self, *args, lr=0.1,**kwargs):
        super(DQN_FC, self).__init__( *args,**kwargs)
        
        # NN Model
        
        ####### FILL IN
        model = Sequential()
        model.add(Flatten(input_shape = (5, 5, self.n_state)))
        model.add(Dense(20, activation = "relu"))
        model.add(Dense(20, activation = "relu"))
        model.add(Dense(4, activation = "linear"))
        
        model.compile(sgd(lr=lr, decay=1e-4, momentum=0.0), "mse")
        self.model = model

# %%
env = Environment(grid_size=size, max_time=T, temperature=0.3)
agent = DQN_FC(size, lr=.1, epsilon = 0.1, memory_size=2000, batch_size = 32)
train(agent, env, epochs_train, prefix='fc_train')
HTML(display_videos('fc_train10.mp4'))
# Out:
# Epoch 000/050 | Loss 0.2100 | Win/lose count 4.5/5.0 (-0.5)
# Epoch 001/050 | Loss 0.4668 | Win/lose count 2.0/5.0 (-3.0)
# Epoch 002/050 | Loss 0.9298 | Win/lose count 2.0/2.0 (0.0)
# Epoch 003/050 | Loss 0.6929 | Win/lose count 3.5/11.0 (-7.5)
# Epoch 004/050 | Loss 0.6780 | Win/lose count 4.0/2.0 (2.0)
# Epoch 005/050 | Loss 0.5215 | Win/lose count 3.5/3.0 (0.5)
# Epoch 006/050 | Loss 0.5694 | Win/lose count 3.5/6.0 (-2.5)
# Epoch 007/050 | Loss 0.7709 | Win/lose count 3.5/2.0 (1.5)
# Epoch 008/050 | Loss 0.7055 | Win/lose count 7.0/3.0 (4.0)
# Epoch 009/050 | Loss 0.6481 | Win/lose count 4.0/5.0 (-1.0)
# Epoch 010/050 | Loss 0.6080 | Win/lose count 3.5/1.0 (2.5)
# Epoch 011/050 | Loss 0.5542 | Win/lose count 3.5/7.0 (-3.5)
# Epoch 012/050 | Loss 0.5710 | Win/lose count 5.0/5.0 (0.0)
# Epoch 013/050 | Loss 0.5817 | Win/lose count 3.0/4.0 (-1.0)
# Epoch 014/050 | Loss 0.5273 | Win/lose count 2.5/4.0 (-1.5)
# Epoch 015/050 | Loss 0.4544 | Win/lose count 5.5/2.0 (3.5)
# Epoch 016/050 | Loss 0.5308 | Win/lose count 5.0/2.0 (3.0)
# Epoch 017/050 | Loss 0.5105 | Win/lose count 5.0/3.0 (2.0)
# Epoch 018/050 | Loss 0.4639 | Win/lose count 3.5/2.0 (1.5)
# Epoch 019/050 | Loss 0.5289 | Win/lose count 2.5/1.0 (1.5)
# Epoch 020/050 | Loss 0.4259 | Win/lose count 1.5/3.0 (-1.5)
# Epoch 021/050 | Loss 0.4001 | Win/lose count 2.5/0 (2.5)
# Epoch 022/050 | Loss 0.3776 | Win/lose count 3.0/3.0 (0.0)
# Epoch 023/050 | Loss 0.3857 | Win/lose count 3.0/2.0 (1.0)
# Epoch 024/050 | Loss 0.3726 | Win/lose count 5.0/2.0 (3.0)
# Epoch 025/050 | Loss 0.3752 | Win/lose count 4.0/5.0 (-1.0)
# Epoch 026/050 | Loss 0.3222 | Win/lose count 1.0/2.0 (-1.0)
# Epoch 027/050 | Loss 0.3091 | Win/lose count 3.5/8.0 (-4.5)
# Epoch 028/050 | Loss 0.2907 | Win/lose count 3.0/3.0 (0.0)
# Epoch 029/050 | Loss 0.3145 | Win/lose count 5.0/2.0 (3.0)
# Epoch 030/050 | Loss 0.2651 | Win/lose count 3.5/5.0 (-1.5)
# Epoch 031/050 | Loss 0.2789 | Win/lose count 4.5/4.0 (0.5)
# Epoch 032/050 | Loss 0.2282 | Win/lose count 5.5/7.0 (-1.5)
# Epoch 033/050 | Loss 0.2726 | Win/lose count 6.0/3.0 (3.0)
# Epoch 034/050 | Loss 0.2791 | Win/lose count 6.5/5.0 (1.5)
# Epoch 035/050 | Loss 0.2527 | Win/lose count 3.0/4.0 (-1.0)
# Epoch 036/050 | Loss 0.2311 | Win/lose count 5.0/2.0 (3.0)
# Epoch 037/050 | Loss 0.2115 | Win/lose count 6.5/8.0 (-1.5)
# Epoch 038/050 | Loss 0.1869 | Win/lose count 6.5/1.0 (5.5)
# Epoch 039/050 | Loss 0.1955 | Win/lose count 8.0/9.0 (-1.0)
# Epoch 040/050 | Loss 0.1920 | Win/lose count 5.0/2.0 (3.0)
# Epoch 041/050 | Loss 0.1999 | Win/lose count 4.5/7.0 (-2.5)
# Epoch 042/050 | Loss 0.1926 | Win/lose count 4.0/1.0 (3.0)
# Epoch 043/050 | Loss 0.1852 | Win/lose count 11.0/7.0 (4.0)
# Epoch 044/050 | Loss 0.1656 | Win/lose count 5.5/5.0 (0.5)
# Epoch 045/050 | Loss 0.1827 | Win/lose count 3.5/3.0 (0.5)
# Epoch 046/050 | Loss 0.1623 | Win/lose count 6.0/3.0 (3.0)
# Epoch 047/050 | Loss 0.1511 | Win/lose count 3.5/3.0 (0.5)
# Epoch 048/050 | Loss 0.1976 | Win/lose count 4.0/1.0 (3.0)
# Epoch 049/050 | Loss 0.1966 | Win/lose count 3.0/3.0 (0.0)
# <video alt="test" controls>
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %% [markdown]
# ***
# ***
# __Question 8__ Implement the DQN training algorithm using a CNN (for example, 2 convolutional layers and one final fully connected layer).

# %%
class DQN_CNN(DQN):
    def __init__(self, *args,lr=0.1,**kwargs):
        super(DQN_CNN, self).__init__(*args,**kwargs)
        
        ###### FILL IN
        model = Sequential([
            Conv2D(16, (3, 3), activation='relu', input_shape=(5, 5, self.n_state)),
            Conv2D(8, (3, 3), activation='relu'),
            Flatten(),
            Dense(4),
        ])
        
        model.compile(sgd(lr=lr, decay=1e-4, momentum=0.0), "mse")
        self.model = model

# %%
env = Environment(grid_size=size, max_time=T, temperature=0.3)
agent = DQN_CNN(size, lr=.1, epsilon = 0.1, memory_size=2000, batch_size = 32)
train(agent,env,epochs_train,prefix='cnn_train')
HTML(display_videos('cnn_train10.mp4'))
# Out:
# Epoch 000/050 | Loss 0.0523 | Win/lose count 4.5/3.0 (1.5)
# Epoch 001/050 | Loss 0.0719 | Win/lose count 2.5/2.0 (0.5)
# Epoch 002/050 | Loss 0.1512 | Win/lose count 2.5/2.0 (0.5)
# Epoch 003/050 | Loss 0.2187 | Win/lose count 5.0/7.0 (-2.0)
# Epoch 004/050 | Loss 0.5934 | Win/lose count 5.5/6.0 (-0.5)
# Epoch 005/050 | Loss 1.3633 | Win/lose count 3.5/4.0 (-0.5)
# Epoch 006/050 | Loss 1.6106 | Win/lose count 3.5/7.0 (-3.5)
# Epoch 007/050 | Loss 1.8991 | Win/lose count 1.0/3.0 (-2.0)
# Epoch 008/050 | Loss 1.7338 | Win/lose count 2.5/5.0 (-2.5)
# Epoch 009/050 | Loss 1.8327 | Win/lose count 3.5/7.0 (-3.5)
# Epoch 010/050 | Loss 1.6744 | Win/lose count 3.0/2.0 (1.0)
# Epoch 011/050 | Loss 1.6290 | Win/lose count 5.0/4.0 (1.0)
# Epoch 012/050 | Loss 1.6719 | Win/lose count 6.5/5.0 (1.5)
# Epoch 013/050 | Loss 1.5235 | Win/lose count 2.0/4.0 (-2.0)
# Epoch 014/050 | Loss 1.0946 | Win/lose count 3.5/6.0 (-2.5)
# Epoch 015/050 | Loss 0.8638 | Win/lose count 3.0/2.0 (1.0)
# Epoch 016/050 | Loss 0.6819 | Win/lose count 11.0/4.0 (7.0)
# Epoch 017/050 | Loss 0.6816 | Win/lose count 6.0/3.0 (3.0)
# Epoch 018/050 | Loss 0.6579 | Win/lose count 6.0/4.0 (2.0)
# Epoch 019/050 | Loss 0.6960 | Win/lose count 3.0/3.0 (0.0)
# Epoch 020/050 | Loss 0.6377 | Win/lose count 10.0/0 (10.0)
# Epoch 021/050 | Loss 0.6941 | Win/lose count 5.0/2.0 (3.0)
# Epoch 022/050 | Loss 0.6002 | Win/lose count 1.5/3.0 (-1.5)
# Epoch 023/050 | Loss 0.6553 | Win/lose count 5.0/0 (5.0)
# Epoch 024/050 | Loss 0.6370 | Win/lose count 7.0/4.0 (3.0)
# Epoch 025/050 | Loss 0.6814 | Win/lose count 5.5/1.0 (4.5)
# Epoch 026/050 | Loss 0.7004 | Win/lose count 6.0/4.0 (2.0)
# Epoch 027/050 | Loss 0.7723 | Win/lose count 4.5/3.0 (1.5)
# Epoch 028/050 | Loss 0.7848 | Win/lose count 5.5/2.0 (3.5)
# Epoch 029/050 | Loss 0.7800 | Win/lose count 8.5/3.0 (5.5)
# Epoch 030/050 | Loss 0.7205 | Win/lose count 4.5/2.0 (2.5)
# Epoch 031/050 | Loss 0.6627 | Win/lose count 6.5/2.0 (4.5)
# Epoch 032/050 | Loss 0.6566 | Win/lose count 8.0/2.0 (6.0)
# Epoch 033/050 | Loss 0.5981 | Win/lose count 15.5/0 (15.5)
# Epoch 034/050 | Loss 0.6195 | Win/lose count 2.5/1.0 (1.5)
# Epoch 035/050 | Loss 0.5961 | Win/lose count 3.5/1.0 (2.5)
# Epoch 036/050 | Loss 0.5273 | Win/lose count 6.0/3.0 (3.0)
# Epoch 037/050 | Loss 0.4963 | Win/lose count 4.0/0 (4.0)
# Epoch 038/050 | Loss 0.5080 | Win/lose count 5.0/5.0 (0.0)
# Epoch 039/050 | Loss 0.5147 | Win/lose count 9.0/3.0 (6.0)
# Epoch 040/050 | Loss 0.4360 | Win/lose count 8.0/4.0 (4.0)
# Epoch 041/050 | Loss 0.4097 | Win/lose count 4.0/1.0 (3.0)
# Epoch 042/050 | Loss 0.4305 | Win/lose count 6.0/3.0 (3.0)
# Epoch 043/050 | Loss 0.3885 | Win/lose count 8.5/3.0 (5.5)
# Epoch 044/050 | Loss 0.3552 | Win/lose count 8.0/3.0 (5.0)
# Epoch 045/050 | Loss 0.3541 | Win/lose count 8.5/1.0 (7.5)
# Epoch 046/050 | Loss 0.3624 | Win/lose count 9.5/5.0 (4.5)
# Epoch 047/050 | Loss 0.3487 | Win/lose count 8.0/1.0 (7.0)
# Epoch 048/050 | Loss 0.3299 | Win/lose count 6.0/4.0 (2.0)
# Epoch 049/050 | Loss 0.3186 | Win/lose count 3.5/1.0 (2.5)
# <video alt="test" controls>
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %% [markdown]
# ***
# ***
# __Question 9__ Test both algorithms and compare their performances. Which issue(s) do you observe? Observe also different behaviors by changing the temperature.

# %%
env = Environment(grid_size=size, max_time=T,temperature=0.5)
agent_cnn = DQN_CNN(size, lr=.1, epsilon = 0.1, memory_size=2000, batch_size = 32)
agent_cnn.load(name_weights='cnn_trainmodel.h5',name_model='cnn_trainmodel.json')

agent_fc = DQN_FC(size, lr=.1, epsilon = 0.1, memory_size=2000, batch_size = 32)
agent_cnn.load(name_weights='fc_trainmodel.h5',name_model='fc_trainmodel.json')
print('Test of the CNN')
test(agent_cnn,env,epochs_test,prefix='cnn_test')
print('Test of the FC')
test(agent_fc,env,epochs_test,prefix='fc_test')
# Out:
# Test of the CNN
# Win/lose count 9.0/5.0. Average score (4.0)
# Win/lose count 7.5/3.0. Average score (4.25)
# Win/lose count 4.5/5.0. Average score (2.6666666666666665)
# Win/lose count 6.5/5.0. Average score (2.375)
# Win/lose count 8.0/6.0. Average score (2.3)
# Win/lose count 9.5/3.0. Average score (3.0)
# Win/lose count 8.5/7.0. Average score (2.7857142857142856)
# Win/lose count 11.5/8.0. Average score (2.875)
# Win/lose count 5.0/2.0. Average score (2.888888888888889)
# Win/lose count 8.0/5.0. Average score (2.9)
# Win/lose count 8.0/3.0. Average score (3.090909090909091)
# Win/lose count 7.5/8.0. Average score (2.7916666666666665)
# Win/lose count 6.5/3.0. Average score (2.8461538461538463)
# Win/lose count 7.5/10.0. Average score (2.4642857142857144)
# Win/lose count 11.5/5.0. Average score (2.7333333333333334)
# Win/lose count 6.0/9.0. Average score (2.375)
# Win/lose count 4.5/1.0. Average score (2.4411764705882355)
# Win/lose count 5.0/5.0. Average score (2.3055555555555554)
# Win/lose count 6.0/6.0. Average score (2.1842105263157894)
# Win/lose count 14.5/2.0. Average score (2.7)
# Win/lose count 9.0/7.0. Average score (2.6666666666666665)
# Win/lose count 5.0/4.0. Average score (2.590909090909091)
# Win/lose count 6.0/1.0. Average score (2.6956521739130435)
# Win/lose count 7.0/5.0. Average score (2.6666666666666665)
# Win/lose count 8.0/5.0. Average score (2.68)
# Win/lose count 5.0/1.0. Average score (2.730769230769231)
# Win/lose count 4.0/1.0. Average score (2.740740740740741)
# Win/lose count 10.0/6.0. Average score (2.7857142857142856)
# Win/lose count 9.0/4.0. Average score (2.8620689655172415)
# Win/lose count 8.0/8.0. Average score (2.7666666666666666)
# Win/lose count 4.5/2.0. Average score (2.7580645161290325)
# Win/lose count 6.0/3.0. Average score (2.765625)
# Win/lose count 4.5/6.0. Average score (2.6363636363636362)
# Win/lose count 9.5/3.0. Average score (2.75)
# Win/lose count 1.5/1.0. Average score (2.6857142857142855)
# Win/lose count 7.5/3.0. Average score (2.736111111111111)
# Win/lose count 5.0/6.0. Average score (2.635135135135135)
# Win/lose count 4.0/4.0. Average score (2.5657894736842106)
# Win/lose count 10.5/3.0. Average score (2.6923076923076925)
# Win/lose count 7.0/2.0. Average score (2.75)
# Win/lose count 7.5/4.0. Average score (2.768292682926829)
# Win/lose count 2.5/3.0. Average score (2.6904761904761907)
# Win/lose count 7.5/2.0. Average score (2.755813953488372)
# Win/lose count 6.0/5.0. Average score (2.715909090909091)
# Win/lose count 4.5/7.0. Average score (2.6)
# Win/lose count 9.5/6.0. Average score (2.619565217391304)
# Win/lose count 7.5/3.0. Average score (2.6595744680851063)
# Win/lose count 9.5/10.0. Average score (2.59375)
# Win/lose count 18.5/6.0. Average score (2.795918367346939)
# Win/lose count 7.0/6.0. Average score (2.76)
# Final score: 2.76
# Test of the FC
# Win/lose count 8.0/8.0. Average score (0.0)
# Win/lose count 2.5/2.0. Average score (0.25)
# Win/lose count 2.0/8.0. Average score (-1.8333333333333333)
# Win/lose count 10.5/16.0. Average score (-2.75)
# Win/lose count 5.5/7.0. Average score (-2.5)
# Win/lose count 7.0/8.0. Average score (-2.25)
# Win/lose count 6.0/6.0. Average score (-1.9285714285714286)
# Win/lose count 11.0/13.0. Average score (-1.9375)
# Win/lose count 6.0/7.0. Average score (-1.8333333333333333)
# Win/lose count 6.0/5.0. Average score (-1.55)
# Win/lose count 6.0/6.0. Average score (-1.4090909090909092)
# Win/lose count 10.0/12.0. Average score (-1.4583333333333333)
# Win/lose count 4.5/7.0. Average score (-1.5384615384615385)
# Win/lose count 5.5/6.0. Average score (-1.4642857142857142)
# Win/lose count 5.0/7.0. Average score (-1.5)
# Win/lose count 5.5/3.0. Average score (-1.25)
# Win/lose count 5.0/8.0. Average score (-1.3529411764705883)
# Win/lose count 5.0/9.0. Average score (-1.5)
# Win/lose count 3.0/6.0. Average score (-1.5789473684210527)
# Win/lose count 4.0/10.0. Average score (-1.8)
# Win/lose count 5.0/8.0. Average score (-1.8571428571428572)
# Win/lose count 4.0/5.0. Average score (-1.8181818181818181)
# Win/lose count 2.5/8.0. Average score (-1.9782608695652173)
# Win/lose count 7.5/7.0. Average score (-1.875)
# Win/lose count 6.0/4.0. Average score (-1.72)
# Win/lose count 9.0/15.0. Average score (-1.8846153846153846)
# Win/lose count 6.0/4.0. Average score (-1.7407407407407407)
# Win/lose count 11.0/9.0. Average score (-1.6071428571428572)
# Win/lose count 3.0/2.0. Average score (-1.5172413793103448)
# Win/lose count 4.5/8.0. Average score (-1.5833333333333333)
# Win/lose count 4.5/8.0. Average score (-1.6451612903225807)
# Win/lose count 10.0/7.0. Average score (-1.5)
# Win/lose count 9.0/11.0. Average score (-1.5151515151515151)
# Win/lose count 2.5/5.0. Average score (-1.5441176470588236)
# Win/lose count 6.5/6.0. Average score (-1.4857142857142858)
# Win/lose count 6.0/13.0. Average score (-1.6388888888888888)
# Win/lose count 6.5/2.0. Average score (-1.472972972972973)
# Win/lose count 3.0/5.0. Average score (-1.486842105263158)
# Win/lose count 3.0/2.0. Average score (-1.4230769230769231)
# Win/lose count 7.0/8.0. Average score (-1.4125)
# Win/lose count 7.5/9.0. Average score (-1.4146341463414633)
# Win/lose count 4.5/9.0. Average score (-1.4880952380952381)
# Win/lose count 9.0/6.0. Average score (-1.3837209302325582)
# Win/lose count 3.5/5.0. Average score (-1.3863636363636365)
# Win/lose count 2.0/11.0. Average score (-1.5555555555555556)
# Win/lose count 5.5/5.0. Average score (-1.5108695652173914)
# Win/lose count 8.0/5.0. Average score (-1.4148936170212767)
# Win/lose count 6.0/13.0. Average score (-1.53125)
# Win/lose count 4.0/2.0. Average score (-1.4591836734693877)
# Win/lose count 2.5/1.0. Average score (-1.4)
# Final score: -1.4

# %%
HTML(display_videos('cnn_test10.mp4'))
# Out:
# <video alt="test" controls>
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %%
HTML(display_videos('fc_test10.mp4'))
# Out:
# <video alt="test" controls>
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %% [markdown]
# Based on the FC and CNN designed earlier, CNN performs better than FC. And at higher temperature, both performs better.

# %% [markdown]
# ***
#
# The algorithm tends to not explore the map which can be an issue. We propose two ideas in order to encourage exploration:
# 1. Incorporating a decreasing $\epsilon$-greedy exploration. You can use the method ```set_epsilon```
# 2. Append via the environment a new state that describes if a cell has been visited or not
#
# ***
# __Question 10__ Design a new ```train_explore``` function and environment class ```EnvironmentExploring``` to tackle the issue of exploration.

# %%
def train_explore(agent,env,epoch,prefix=''):
    # Number of won games
    score = 0
    loss = 0

    for e in range(epoch):
        if (e%10 == 0):
            agent.Learning_rate = 1/(e/10+1)
            print(agent.Learning_rate)
        if (e%10 == 0):
            agent.set_epsilon(2*agent.epsilon/(e/10+1))
            print(agent.epsilon)
        
        # At each epoch, we restart to a fresh game and get the initial state
        state = env.reset()
        # This assumes that the games will terminate
        game_over = False

        win = 0
        lose = 0

        while not game_over:
            # The agent performs an action
            action = agent.act(state)

            # Apply an action to the environment, get the next state, the reward
            # and if the games end
            prev_state = state
            
            # add train = True
            state, reward, game_over = env.act(action, train=True)

            # Update the counters
            if reward > 0:
                win = win + reward
            if reward < 0:
                lose = lose -reward

            # Apply the reinforcement strategy
            loss = agent.reinforce(prev_state, state,  action, reward, game_over)

        # Save as a mp4
        if e % 10 == 0:
            env.draw(prefix+str(e))

        # Update stats
        score += win-lose

        print("Epoch {:03d}/{:03d} | Loss {:.4f} | Win/lose count {}/{} ({})"
              .format(e, epoch, loss, win, lose, win-lose))
        agent.save(name_weights=prefix+'model.h5',name_model=prefix+'model.json')
        
class EnvironmentExploring(object):
    def __init__(self, grid_size=10, max_time=500, temperature=0.1):
        grid_size = grid_size+4
        self.grid_size = grid_size
        self.max_time = max_time
        self.temperature = temperature

        #board on which one plays
        self.board = np.zeros((grid_size,grid_size))
        self.position = np.zeros((grid_size,grid_size))
        
        # add malus_position 
        self.malus_position = np.zeros((grid_size,grid_size))

        # coordinate of the cat
        self.x = 0
        self.y = 1

        # self time
        self.t = 0

        self.scale=16

        self.to_draw = np.zeros((max_time+2, grid_size*self.scale, grid_size*self.scale, 3))


    def draw(self,e):
        skvideo.io.vwrite(str(e) + '.mp4', self.to_draw)

    def get_frame(self,t):
        b = np.zeros((self.grid_size,self.grid_size,3))+128
        b[self.board>0,0] = 256
        b[self.board < 0, 2] = 256
        b[self.x,self.y,:]=256
        b[-2:,:,:]=0
        b[:,-2:,:]=0
        b[:2,:,:]=0
        b[:,:2,:]=0
        
        b =  cv2.resize(b, None, fx=self.scale, fy=self.scale, interpolation=cv2.INTER_NEAREST)

        self.to_draw[t,:,:,:]=b


    def act(self, action, train=True):
        """This function returns the new state, reward and decides if the
        game ends."""

        self.get_frame(int(self.t))

        self.position = np.zeros((self.grid_size, self.grid_size))

        self.position[0:2,:]= -1
        self.position[:,0:2] = -1
        self.position[-2:, :] = -1
        self.position[:, -2:] = -1

        self.position[self.x, self.y] = 1
        if action == 0:
            if self.x == self.grid_size-3:
                self.x = self.x-1
            else:
                self.x = self.x + 1
        elif action == 1:
            if self.x == 2:
                self.x = self.x+1
            else:
                self.x = self.x-1
        elif action == 2:
            if self.y == self.grid_size - 3:
                self.y = self.y - 1
            else:
                self.y = self.y + 1
        elif action == 3:
            if self.y == 2:
                self.y = self.y + 1
            else:
                self.y = self.y - 1
        else:
            RuntimeError('Error: action not recognized')
        
        # Change reward calculation
        reward = 0
        if train:
            reward = -self.malus_position[self.x, self.y]
        self.malus_position[self.x, self.y] = 0.3

        reward = reward + self.board[self.x, self.y]
        
        
        self.t = self.t + 1
        self.board[self.x, self.y] = 0
        game_over = self.t > self.max_time
        # 3 "feature" states instead of 2
        state = np.concatenate((self.malus_position.reshape(self.grid_size, self.grid_size,1),
                                self.board.reshape(self.grid_size, self.grid_size,1),
                        self.position.reshape(self.grid_size, self.grid_size,1)),axis=2)
        state = state[self.x-2:self.x+3,self.y-2:self.y+3,:]

        return state, reward, game_over

    def reset(self):
        """This function resets the game and returns the initial state"""

        self.x = np.random.randint(3, self.grid_size-3, size=1)[0]
        self.y = np.random.randint(3, self.grid_size-3, size=1)[0]


        bonus = 0.5*np.random.binomial(1,self.temperature,size=self.grid_size**2)
        bonus = bonus.reshape(self.grid_size,self.grid_size)

        malus = -1.0*np.random.binomial(1,self.temperature,size=self.grid_size**2)
        malus = malus.reshape(self.grid_size, self.grid_size)

        self.to_draw = np.zeros((self.max_time+2, self.grid_size*self.scale, self.grid_size*self.scale, 3))


        malus[bonus>0]=0

        self.board = bonus + malus

        # add malus_position 
        self.malus_position = np.zeros((self.grid_size,self.grid_size))
        
        self.position = np.zeros((self.grid_size, self.grid_size))
        self.position[0:2,:]= -1
        self.position[:,0:2] = -1
        self.position[-2:, :] = -1
        self.position[:,-2:] = -1
        self.board[self.x,self.y] = 0
        self.t = 0

        state = np.concatenate((self.malus_position.reshape(self.grid_size, self.grid_size,1),
                                self.board.reshape(self.grid_size, self.grid_size,1),
                        self.position.reshape(self.grid_size, self.grid_size,1)),axis=2)

        state = state[self.x - 2:self.x + 3, self.y - 2:self.y + 3, :]
        return state

# %%
# Training
env = EnvironmentExploring(grid_size=size, max_time=T, temperature=0.3)
agent = DQN_CNN(size, lr=.1, epsilon = 0.1, memory_size=2000, batch_size = 32,n_state=3)
train_explore(agent, env, epochs_train, prefix='cnn_train_explore')
HTML(display_videos('cnn_train_explore10.mp4'))
# Out:
# 1.0
# 0.2
# Epoch 000/050 | Loss 0.0247 | Win/lose count 10.5/54.99999999999983 (-44.49999999999983)
# Epoch 001/050 | Loss 1.3142 | Win/lose count 6.0/55.399999999999835 (-49.399999999999835)
# Epoch 002/050 | Loss 1.5880 | Win/lose count 14.0/49.399999999999935 (-35.399999999999935)
# Epoch 003/050 | Loss 1.6084 | Win/lose count 8.5/50.79999999999987 (-42.29999999999987)
# Epoch 004/050 | Loss 1.6208 | Win/lose count 8.5/49.69999999999988 (-41.19999999999988)
# Epoch 005/050 | Loss 1.4962 | Win/lose count 13.5/38.999999999999986 (-25.499999999999986)
# Epoch 006/050 | Loss 1.6059 | Win/lose count 12.0/49.39999999999993 (-37.39999999999993)
# Epoch 007/050 | Loss 1.4260 | Win/lose count 11.0/48.29999999999993 (-37.29999999999993)
# Epoch 008/050 | Loss 1.3342 | Win/lose count 14.0/42.49999999999996 (-28.499999999999957)
# Epoch 009/050 | Loss 1.2250 | Win/lose count 24.5/34.200000000000045 (-9.700000000000045)
# 0.5
# 0.2
# Epoch 010/050 | Loss 1.2271 | Win/lose count 20.0/30.700000000000042 (-10.700000000000042)
# Epoch 011/050 | Loss 1.0856 | Win/lose count 21.0/37.200000000000024 (-16.200000000000024)
# Epoch 012/050 | Loss 0.6603 | Win/lose count 20.0/35.80000000000001 (-15.800000000000011)
# Epoch 013/050 | Loss 0.5042 | Win/lose count 19.5/33.000000000000036 (-13.500000000000036)
# Epoch 014/050 | Loss 0.4377 | Win/lose count 19.5/37.599999999999994 (-18.099999999999994)
# Epoch 015/050 | Loss 0.3192 | Win/lose count 18.0/31.000000000000043 (-13.000000000000043)
# Epoch 016/050 | Loss 0.2990 | Win/lose count 24.5/31.200000000000042 (-6.700000000000042)
# Epoch 017/050 | Loss 0.2035 | Win/lose count 23.0/33.00000000000003 (-10.000000000000028)
# Epoch 018/050 | Loss 0.2811 | Win/lose count 18.5/40.899999999999956 (-22.399999999999956)
# Epoch 019/050 | Loss 0.7067 | Win/lose count 25.5/34.00000000000002 (-8.500000000000021)
# 0.3333333333333333
# 0.13333333333333333
# Epoch 020/050 | Loss 0.3707 | Win/lose count 21.0/33.70000000000003 (-12.700000000000031)
# Epoch 021/050 | Loss 0.6752 | Win/lose count 24.5/34.90000000000003 (-10.400000000000027)
# Epoch 022/050 | Loss 0.5601 | Win/lose count 20.0/36.400000000000006 (-16.400000000000006)
# Epoch 023/050 | Loss 0.4946 | Win/lose count 22.5/34.20000000000003 (-11.700000000000031)
# Epoch 024/050 | Loss 0.3107 | Win/lose count 22.0/36.900000000000006 (-14.900000000000006)
# Epoch 025/050 | Loss 0.5661 | Win/lose count 17.5/37.199999999999996 (-19.699999999999996)
# Epoch 026/050 | Loss 0.6001 | Win/lose count 22.5/33.90000000000002 (-11.40000000000002)
# Epoch 027/050 | Loss 0.5634 | Win/lose count 22.0/37.39999999999999 (-15.399999999999991)
# Epoch 028/050 | Loss 0.7039 | Win/lose count 19.5/36.99999999999999 (-17.499999999999993)
# Epoch 029/050 | Loss 0.5309 | Win/lose count 22.5/38.099999999999994 (-15.599999999999994)
# 0.25
# 0.06666666666666667
# Epoch 030/050 | Loss 0.6300 | Win/lose count 23.5/31.400000000000045 (-7.900000000000045)
# Epoch 031/050 | Loss 0.5437 | Win/lose count 20.0/35.100000000000016 (-15.100000000000016)
# Epoch 032/050 | Loss 0.4365 | Win/lose count 14.5/46.29999999999992 (-31.79999999999992)
# Epoch 033/050 | Loss 0.4982 | Win/lose count 20.0/38.49999999999999 (-18.499999999999993)
# Epoch 034/050 | Loss 0.5415 | Win/lose count 18.0/36.2 (-18.200000000000003)
# Epoch 035/050 | Loss 0.4471 | Win/lose count 17.0/44.69999999999992 (-27.699999999999918)
# Epoch 036/050 | Loss 0.5883 | Win/lose count 25.0/32.40000000000004 (-7.400000000000041)
# Epoch 037/050 | Loss 0.5320 | Win/lose count 18.0/37.300000000000004 (-19.300000000000004)
# Epoch 038/050 | Loss 0.6110 | Win/lose count 24.0/29.700000000000042 (-5.700000000000042)
# Epoch 039/050 | Loss 0.4539 | Win/lose count 16.0/42.399999999999935 (-26.399999999999935)
# 0.2
# 0.026666666666666665
# Epoch 040/050 | Loss 0.4115 | Win/lose count 16.5/36.7 (-20.200000000000003)
# Epoch 041/050 | Loss 0.4430 | Win/lose count 22.5/34.30000000000002 (-11.800000000000018)
# Epoch 042/050 | Loss 0.6184 | Win/lose count 26.0/35.20000000000002 (-9.200000000000017)
# Epoch 043/050 | Loss 0.5063 | Win/lose count 22.5/37.599999999999994 (-15.099999999999994)
# Epoch 044/050 | Loss 0.7056 | Win/lose count 18.5/38.29999999999999 (-19.79999999999999)
# Epoch 045/050 | Loss 0.4275 | Win/lose count 20.0/41.59999999999996 (-21.59999999999996)
# Epoch 046/050 | Loss 0.4947 | Win/lose count 26.5/33.10000000000003 (-6.60000000000003)
# Epoch 047/050 | Loss 0.5188 | Win/lose count 26.0/33.60000000000002 (-7.600000000000023)
# Epoch 048/050 | Loss 0.6208 | Win/lose count 19.5/39.899999999999984 (-20.399999999999984)
# Epoch 049/050 | Loss 0.5480 | Win/lose count 23.0/36.099999999999994 (-13.099999999999994)
# <video alt="test" controls>
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %%
# Evaluation
test(agent,env,epochs_test,prefix='cnn_test_explore')
HTML(display_videos('cnn_test_explore10.mp4'))
# Out:
# Win/lose count 22.0/37.3. Average score (-15.299999999999997)
# Win/lose count 19.0/38.999999999999986. Average score (-17.64999999999999)
# Win/lose count 15.0/39.799999999999976. Average score (-20.03333333333332)
# Win/lose count 17.0/37.800000000000026. Average score (-20.224999999999994)
# Win/lose count 18.5/48.29999999999992. Average score (-22.13999999999998)
# Win/lose count 14.0/46.299999999999926. Average score (-23.833333333333304)
# Win/lose count 8.5/50.59999999999987. Average score (-26.4428571428571)
# Win/lose count 18.5/39.79999999999998. Average score (-25.79999999999996)
# Win/lose count 19.0/43.199999999999946. Average score (-25.62222222222218)
# Win/lose count 22.5/35.200000000000024. Average score (-24.329999999999963)
# Win/lose count 13.0/43.39999999999994. Average score (-24.881818181818144)
# Win/lose count 19.0/40.99999999999996. Average score (-24.641666666666627)
# Win/lose count 4.5/53.69999999999985. Average score (-26.530769230769184)
# Win/lose count 19.5/38.49999999999998. Average score (-25.9928571428571)
# Win/lose count 21.0/39.49999999999998. Average score (-25.493333333333293)
# Win/lose count 17.5/39.39999999999998. Average score (-25.26874999999996)
# Win/lose count 8.5/43.199999999999946. Average score (-25.823529411764667)
# Win/lose count 5.5/52.59999999999986. Average score (-27.00555555555551)
# Win/lose count 2.0/57.29999999999981. Average score (-28.49473684210521)
# Win/lose count 21.5/36.50000000000001. Average score (-27.819999999999947)
# Win/lose count 18.0/47.199999999999896. Average score (-27.885714285714233)
# Win/lose count 17.5/38.999999999999986. Average score (-27.595454545454494)
# Win/lose count 16.0/42.99999999999996. Average score (-27.569565217391254)
# Win/lose count 14.5/45.59999999999992. Average score (-27.716666666666615)
# Win/lose count 10.5/50.99999999999987. Average score (-28.22799999999995)
# Win/lose count 11.5/45.89999999999991. Average score (-28.465384615384558)
# Win/lose count 11.0/45.199999999999925. Average score (-28.67777777777772)
# Win/lose count 20.0/42.59999999999997. Average score (-28.460714285714232)
# Win/lose count 18.5/42.59999999999995. Average score (-28.310344827586153)
# Win/lose count 16.5/37.00000000000001. Average score (-28.049999999999947)
# Win/lose count 15.0/42.299999999999955. Average score (-28.02580645161285)
# Win/lose count 15.5/41.499999999999964. Average score (-27.96249999999995)
# Win/lose count 13.0/50.99999999999987. Average score (-28.266666666666612)
# Win/lose count 15.5/35.000000000000014. Average score (-28.008823529411714)
# Win/lose count 21.0/36.400000000000006. Average score (-27.648571428571376)
# Win/lose count 21.5/39.100000000000016. Average score (-27.369444444444397)
# Win/lose count 14.5/42.399999999999956. Average score (-27.383783783783734)
# Win/lose count 18.5/36.40000000000001. Average score (-27.134210526315744)
# Win/lose count 12.0/44.49999999999993. Average score (-27.271794871794828)
# Win/lose count 18.5/41.19999999999995. Average score (-27.15749999999996)
# Win/lose count 14.0/47.89999999999992. Average score (-27.32195121951215)
# Win/lose count 15.5/44.29999999999993. Average score (-27.357142857142815)
# Win/lose count 8.5/46.499999999999936. Average score (-27.604651162790656)
# Win/lose count 14.0/48.199999999999896. Average score (-27.754545454545408)
# Win/lose count 21.0/37.700000000000024. Average score (-27.508888888888844)
# Win/lose count 21.0/39.699999999999974. Average score (-27.317391304347783)
# Win/lose count 5.5/54.99999999999984. Average score (-27.789361702127614)
# Win/lose count 10.5/49.89999999999989. Average score (-28.031249999999954)
# Win/lose count 6.5/54.19999999999984. Average score (-28.43265306122444)
# Win/lose count 17.0/44.99999999999995. Average score (-28.42399999999995)
# Final score: -28.42399999999995
# <video alt="test" controls>
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %% [markdown]
# ***
# ***
# __BONUS question__ Use the expert DQN from the previous question to generate some winning games. Train a model that mimicks its behavior. Compare the performances.

# %% [markdown]
# ***
